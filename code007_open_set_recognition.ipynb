# %%
'''
Let's import useful and "standard" packages.
Not all packages will be used in the short course.
'''

import numpy as np # numpy is a powerful package for numeric calculation, we rename it as "np"
import sys, os # these are system related packages
import pickle # pickle is a cute package to save and load your custom data
import shutil # for high-level file operations
import scipy, sklearn, skimage, math # these are useful packages for scientific computing, machine learning, image processing, and math calculation
import matplotlib.pyplot as plt # this is a powerful package for visualization, e.g., curves, bar charts, histograms, and various visualizations.
import cv2 # this is a powerful package for computer vision
from pathlib import Path
from PIL import Image
from sklearn.metrics import confusion_matrix
import random

# %%
'''
Let's import the famous PyTorch package, supporting deep learning.
It is convenient to give short names for useful functions inside PyTorch
'''
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torchvision.models as models
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.nn.functional as F
from torch.autograd import Variable
import torchvision
from torchvision import datasets, models, transforms
from torchvision.transforms import v2

# %%
def seed_everything(seed=42):
    """
    Sets the random seed for reproducibility across multiple libraries and devices.
    """
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed) # if you are using multi-GPU
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False # set to False for deterministic behavior
    # torch.backends.cudnn.enabled = False # can be set to False if needed
    print(f"Random seed set to {seed}")

# Usage:
seed_everything(0)
# Out:
# Random seed set to 0

# %%
# Set the global random seed for reproducibility
np.random.seed(0)


# set device, which gpu to use.
device ='cpu'
if torch.cuda.is_available():
    device='cuda:0'
print(device)
# Out:
# cuda:0

# %%
# Check the specifications of your machine/what resources you have been allocated through Colab.
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Mon Jul 20 06:50:27 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   46C    P8             12W /   70W |       3MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
from google.colab import drive # you can allow Google Colab to access your google drive, where you can save your data
drive.mount('/content/drive')
root_folder = '/content/drive/MyDrive/OIST-mini-course'
# !ls $root_folder
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# cls_train.pkl
# cls_val.pkl
# code001_part-A_setup.ipynb
# code001_part-B_setup.ipynb
# code001_setup_readme.docx
# code001_setup_readme.pdf
# code002_data_prep_NN.ipynb
# code003_LogReg.ipynb
# code004_DNN_scratch.ipynb
# code005_part-A_detection_dataPrep.ipynb
# code005_part-B_pollen_detection_model_design.ipynb
# code005_part-C_pollen_detection_training.ipynb
# code006_part-A_DNN_finetune.ipynb
# code006_part-B_pollen_detection_finetune.ipynb
# dataset_for_classification
# dataset_for_classification.zip
# dataset_for_detection
# dataset_for_detection.zip
# det_trainval_splits.pkl
# meta_detection.pkl
# slides
# test-image.jpg
# test-image-sharpened.jpg

# %% [markdown]
# # config hyperparameters

# %%
batch_size = 32
epoch_num = 100
lr = 0.0005 # base learning rate
weight_decay = 0.0005


exp_dir = './exp' # experiment directory, used for reading the init model
prefix = 'vanilla'
postfix = 'v1'

project_name = prefix + '_' + postfix   # we save all the checkpoints in this directory
print(project_name)

save_dir = os.path.join(exp_dir, project_name)

log_filename = os.path.join(save_dir, 'train_%f.log' % weight_decay)
print(save_dir)

if not os.path.exists(save_dir): os.makedirs(save_dir)
# Out:
# vanilla_v1
# ./exp/vanilla_v1

# %% [markdown]
# # make PyTorch-friendly dataloaders for train and validation sets

# %%
filename_train = os.path.join(root_folder, 'cls_train.pkl')
filename_val = os.path.join(root_folder, 'cls_val.pkl')

with open(filename_train, 'rb') as file:
    trainset_info = pickle.load(file)

with open(filename_val, 'rb') as file:
    valset_info = pickle.load(file)

train_labellist = trainset_info['train_labellist']
val_labellist = valset_info['val_labellist']

numClasses = max(train_labellist)+1

# %%
unique_labels, counts = np.unique(train_labellist, return_counts=True)


plt.figure(figsize=(8, 6))
plt.bar(unique_labels, counts, color='skyblue', edgecolor='black')

# Add axis labels and title
plt.xlabel('Label')
plt.ylabel('Frequency')
plt.title('Histogram of Labels')

# Add frequency labels on top of the bars
for i in range(len(counts)):
    plt.text(unique_labels[i], counts[i], str(counts[i]), ha='center', va='bottom')

plt.show()

# %% [markdown]
# ## a helper to read data

# %%
class pollenDataset(Dataset):
    def __init__(self, imgpathList, labelList, transform=None, is_trainset=False):
        self.imgpathList = imgpathList
        self.labelList = labelList
        self.transform=transform
        self.current_set_len = len(labelList)
        self.is_trainset = is_trainset

    def __len__(self):
        return self.current_set_len

    def __getitem__(self, idx):
        cur_img = self.imgpathList[idx]
        cur_label = self.labelList[idx]
        cur_img = skimage.io.imread(cur_img).astype(np.float32) / 255.0

        cur_img = cur_img[cur_img.shape[0]//2-64:cur_img.shape[0]//2+64,
                          cur_img.shape[1]//2-64:cur_img.shape[1]//2+64,
                          :] # suppose the new feature is a 100x100 square region in image center

        # cur_img = Image.fromarray(cur_img)
        # cur_img = Image.open(cur_img)
        # print(cur_img.max(),cur_img.min())

        if self.is_trainset:
            if np.random.rand()>0.5:
                cur_img[:,:,0] = np.fliplr(cur_img[:,:,0])
                cur_img[:,:,1] = np.fliplr(cur_img[:,:,1])
                cur_img[:,:,2] = np.fliplr(cur_img[:,:,2])
            if np.random.rand()>0.5:
                cur_img[:,:,0] = np.flipud(cur_img[:,:,0])
                cur_img[:,:,1] = np.flipud(cur_img[:,:,1])
                cur_img[:,:,2] = np.flipud(cur_img[:,:,2])


        if self.transform is not None:
            cur_img = self.transform(cur_img)
            # print('       ', cur_img.max(),cur_img.min())
        return cur_img, cur_label

# %%
IMAGENET_MEAN = [0.485, 0.456, 0.406]
IMAGENET_STD = [0.229, 0.224, 0.225]

data_train_transform = transforms.Compose([
    # v2.RandomResize(min_size=240, max_size=400),
    # transforms.RandomCrop(224),
    # transforms.RandomHorizontalFlip(),
    # transforms.RandomVerticalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(IMAGENET_MEAN, IMAGENET_STD),
])


data_val_transform = transforms.Compose([
    # transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(IMAGENET_MEAN, IMAGENET_STD),
])

# %%
trainset = pollenDataset(imgpathList=trainset_info['train_imgpathlist'],
                         labelList=train_labellist,
                         transform=data_train_transform,
                         is_trainset=True
                        )

valset = pollenDataset(imgpathList=valset_info['val_imgpathlist'],
                       labelList=val_labellist,
                       transform=data_val_transform,
                       is_trainset=False
                      )

# %%
print(len(trainset), len(valset))
# Out:
# 480 120

# %%
dataloader_trainset = DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2)
dataloader_valset = DataLoader(valset, batch_size=batch_size, shuffle=False, num_workers=2)

print(len(dataloader_trainset), len(dataloader_valset))
# Out:
# 15 4

# %%
i = 0
for sample in dataloader_valset:
    i+=1
    if i%10==0:
        print(i, len(dataloader_valset))
    cur_Img, cur_Label = sample
    cur_Img = cur_Img.to(device)
    cur_Label = cur_Label.to(device)

# %%
cur_Img.shape, cur_Label.shape
# Out:
# (torch.Size([24, 3, 128, 128]), torch.Size([24]))

# %% [markdown]
# # Set a Convolutional Neural Network (CNN)

# %%
class ModelArchitecture(nn.Module):
    def __init__(self, num_classes=20, pretrained=False):
        super().__init__()
        if pretrained:
            self.backbone = models.resnet18(weights='IMAGENET1K_V1') # or pretrained=True
        else:
            self.backbone = models.resnet18() # or pretrained=True
        self.backbone.fc = nn.Identity() # remove classification head
        feat_dim = 512
        self.dropout = nn.Dropout(0.5)
        self.cls_head = nn.Linear(feat_dim, num_classes)
    def forward(self, x):
        feat = self.backbone(x)
        feat = self.dropout(feat)
        logits = self.cls_head(feat)
        return logits

# %%
pretrained = True
myModel = ModelArchitecture(num_classes=numClasses, pretrained=pretrained).to(device)
myModel.train()
# Out:
# ModelArchitecture(
#   (backbone): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Identity()
#   )
#   (dropout): Dropout(p=0.5, inplace=False)
#   (cls_head): Linear(in_features=512, out_features=24, bias=True)
# )

# %%
output = myModel(cur_Img)

# %%
loss_fn = nn.CrossEntropyLoss()
# optimizer = optim.AdamW(myModel.parameters(), lr=lr, betas=(0.9, 0.999), weight_decay=weight_decay)

# optimizer = optim.AdamW(myModel.parameters(), lr=lr, betas=(0.9, 0.999), weight_decay=weight_decay)
optimizer = optim.AdamW([
    {'params': myModel.backbone.parameters(), 'lr': 0.00001, 'weight_decay':weight_decay},
    {'params': myModel.cls_head.parameters(), 'lr': 0.0001, 'weight_decay':weight_decay}])

scheduler = lr_scheduler.CosineAnnealingLR(optimizer, epoch_num, eta_min=0)

# %% [markdown]
# # Train this CNN

# %%
def append_to_log(log_filename, content_string):
    fn = open(log_filename,'a')
    fn.write('{}\n'.format(content_string))
    fn.close()

# %%
best_epoch_id = -1
best_loss = torch.inf
list_val_loss = np.zeros(epoch_num)
list_train_loss = np.zeros(epoch_num)


bestmodel_filename = os.path.join(save_dir, 'bestmodel_%f.params' % weight_decay)


fn = open(log_filename,'w')
fn.write('{}\n'.format(project_name))
fn.close()

for epoch in range(epoch_num):
    # training
    cur_string = 'epoch %d/%d...' % (epoch, epoch_num)
    print(cur_string)
    append_to_log(log_filename, cur_string)

    myModel.train();
    cur_loss = 0
    i=0
    for sample in dataloader_trainset:
        i+=1
        if i%20==0:
            cur_string = '\t%d / %d' %(i, len(dataloader_trainset))
            print(cur_string)
            append_to_log(log_filename, cur_string)

        cur_Img, cur_Label = sample
        cur_Img = cur_Img.to(device)
        cur_Label = cur_Label.to(device)
        optimizer.zero_grad()
        output = myModel(cur_Img)
        loss = loss_fn(output, cur_Label)
        cur_loss += loss.data

        # backward pass
        loss.backward()

        # update weights
        optimizer.step()

    scheduler.step()
    cur_loss = cur_loss / len(dataloader_trainset)
    list_train_loss[epoch] = cur_loss
    cur_string = '\ttrain CE: %.4f' % (cur_loss)
    print(cur_string)
    append_to_log(log_filename, cur_string)

    # evaluation
    cur_string = '   evaluation...'
    print(cur_string)
    append_to_log(log_filename, cur_string)
    myModel.eval();
    cur_loss = 0
    for sample in dataloader_valset:
        cur_Img, cur_Label = sample
        cur_Img = cur_Img.to(device)
        cur_Label = cur_Label.to(device)
        output = myModel(cur_Img)
        tmp = loss_fn(output, cur_Label)
        cur_loss += tmp.data
    cur_loss = cur_loss/len(dataloader_valset)
    list_val_loss[epoch] = cur_loss
    if cur_loss<best_loss:
        best_epoch_id = epoch
        best_loss = cur_loss
        torch.save(myModel.state_dict(), bestmodel_filename)
    cur_string = '\tcurrent CE: %.4f, best CE: %.4f at epoch-%d' % (cur_loss, best_loss, best_epoch_id)
    print(cur_string)
    append_to_log(log_filename, cur_string)
# Out:
# epoch 0/100...
# 	train CE: 3.6782
#    evaluation...
# 	current CE: 3.3274, best CE: 3.3274 at epoch-0
# epoch 1/100...
# 	train CE: 3.3877
#    evaluation...
# 	current CE: 3.1789, best CE: 3.1789 at epoch-1
# epoch 2/100...
# 	train CE: 3.1165
#    evaluation...
# 	current CE: 2.9555, best CE: 2.9555 at epoch-2
# epoch 3/100...
# 	train CE: 2.9661
#    evaluation...
# 	current CE: 2.7463, best CE: 2.7463 at epoch-3
# epoch 4/100...
# 	train CE: 2.7874
#    evaluation...
# 	current CE: 2.5766, best CE: 2.5766 at epoch-4
# epoch 5/100...
# 	train CE: 2.6110
#    evaluation...
# 	current CE: 2.4320, best CE: 2.4320 at epoch-5
# epoch 6/100...
# 	train CE: 2.4253
#    evaluation...
# 	current CE: 2.3151, best CE: 2.3151 at epoch-6
# epoch 7/100...
# 	train CE: 2.3703
#    evaluation...
# 	current CE: 2.2074, best CE: 2.2074 at epoch-7
# epoch 8/100...
# 	train CE: 2.2212
#    evaluation...
# 	current CE: 2.0993, best CE: 2.0993 at epoch-8
# epoch 9/100...
# 	train CE: 2.0764
#    evaluation...
# 	current CE: 2.0018, best CE: 2.0018 at epoch-9
# epoch 10/100...
# 	train CE: 1.9187
#    evaluation...
# 	current CE: 1.9187, best CE: 1.9187 at epoch-10
# epoch 11/100...
# 	train CE: 1.9306
#    evaluation...
# 	current CE: 1.8300, best CE: 1.8300 at epoch-11
# epoch 12/100...
# 	train CE: 1.7078
#    evaluation...
# 	current CE: 1.7598, best CE: 1.7598 at epoch-12
# epoch 13/100...
# 	train CE: 1.6591
#    evaluation...
# 	current CE: 1.7039, best CE: 1.7039 at epoch-13
# epoch 14/100...
# 	train CE: 1.5571
#    evaluation...
# 	current CE: 1.6455, best CE: 1.6455 at epoch-14
# epoch 15/100...
# 	train CE: 1.5503
#    evaluation...
# 	current CE: 1.5929, best CE: 1.5929 at epoch-15
# epoch 16/100...
# 	train CE: 1.4509
#    evaluation...
# 	current CE: 1.5496, best CE: 1.5496 at epoch-16
# epoch 17/100...
# 	train CE: 1.3604
#    evaluation...
# 	current CE: 1.4971, best CE: 1.4971 at epoch-17
# epoch 18/100...
# 	train CE: 1.2893
#    evaluation...
# 	current CE: 1.4590, best CE: 1.4590 at epoch-18
# epoch 19/100...
# 	train CE: 1.2906
#    evaluation...
# 	current CE: 1.4297, best CE: 1.4297 at epoch-19
# epoch 20/100...
# 	train CE: 1.2297
#    evaluation...
# 	current CE: 1.3774, best CE: 1.3774 at epoch-20
# epoch 21/100...
# 	train CE: 1.1466
#    evaluation...
# 	current CE: 1.3301, best CE: 1.3301 at epoch-21
# epoch 22/100...
# 	train CE: 1.1182
#    evaluation...
# 	current CE: 1.3103, best CE: 1.3103 at epoch-22
# epoch 23/100...
# 	train CE: 1.0469
#    evaluation...
# 	current CE: 1.2813, best CE: 1.2813 at epoch-23
# epoch 24/100...
# 	train CE: 0.9581
#    evaluation...
# 	current CE: 1.2511, best CE: 1.2511 at epoch-24
# epoch 25/100...
# 	train CE: 0.9969
#    evaluation...
# 	current CE: 1.2297, best CE: 1.2297 at epoch-25
# epoch 26/100...
# 	train CE: 0.9604
#    evaluation...
# 	current CE: 1.1943, best CE: 1.1943 at epoch-26
# epoch 27/100...
# 	train CE: 0.9584
#    evaluation...
# 	current CE: 1.1786, best CE: 1.1786 at epoch-27
# epoch 28/100...
# 	train CE: 0.8601
#    evaluation...
# 	current CE: 1.1610, best CE: 1.1610 at epoch-28
# epoch 29/100...
# 	train CE: 0.8154
#    evaluation...
# 	current CE: 1.1477, best CE: 1.1477 at epoch-29
# epoch 30/100...
# 	train CE: 0.8530
#    evaluation...
# 	current CE: 1.1329, best CE: 1.1329 at epoch-30
# epoch 31/100...
# 	train CE: 0.8463
#    evaluation...
# 	current CE: 1.1014, best CE: 1.1014 at epoch-31
# epoch 32/100...
# 	train CE: 0.7846
#    evaluation...
# 	current CE: 1.0847, best CE: 1.0847 at epoch-32
# epoch 33/100...
# 	train CE: 0.7615
#    evaluation...
# 	current CE: 1.0812, best CE: 1.0812 at epoch-33
# epoch 34/100...
# 	train CE: 0.6642
#    evaluation...
# 	current CE: 1.0799, best CE: 1.0799 at epoch-34
# epoch 35/100...
# 	train CE: 0.7156
#    evaluation...
# 	current CE: 1.0569, best CE: 1.0569 at epoch-35
# epoch 36/100...
# 	train CE: 0.6650
#    evaluation...
# 	current CE: 1.0501, best CE: 1.0501 at epoch-36
# epoch 37/100...
# 	train CE: 0.6564
#    evaluation...
# 	current CE: 1.0370, best CE: 1.0370 at epoch-37
# epoch 38/100...
# 	train CE: 0.6798
#    evaluation...
# 	current CE: 1.0309, best CE: 1.0309 at epoch-38
# epoch 39/100...
# 	train CE: 0.5968
#    evaluation...
# 	current CE: 1.0211, best CE: 1.0211 at epoch-39
# epoch 40/100...
# 	train CE: 0.5876
#    evaluation...
# 	current CE: 1.0078, best CE: 1.0078 at epoch-40
# epoch 41/100...
# 	train CE: 0.5821
#    evaluation...
# 	current CE: 0.9946, best CE: 0.9946 at epoch-41
# epoch 42/100...
# 	train CE: 0.5743
#    evaluation...
# 	current CE: 0.9805, best CE: 0.9805 at epoch-42
# epoch 43/100...
# 	train CE: 0.5802
#    evaluation...
# 	current CE: 0.9714, best CE: 0.9714 at epoch-43
# epoch 44/100...
# 	train CE: 0.5462
#    evaluation...
# 	current CE: 0.9742, best CE: 0.9714 at epoch-43
# epoch 45/100...
# 	train CE: 0.5187
#    evaluation...
# 	current CE: 0.9765, best CE: 0.9714 at epoch-43
# epoch 46/100...
# 	train CE: 0.5312
#    evaluation...
# 	current CE: 0.9642, best CE: 0.9642 at epoch-46
# epoch 47/100...
# 	train CE: 0.5260
#    evaluation...
# 	current CE: 0.9448, best CE: 0.9448 at epoch-47
# epoch 48/100...
# 	train CE: 0.4623
#    evaluation...
# 	current CE: 0.9305, best CE: 0.9305 at epoch-48
# epoch 49/100...
# 	train CE: 0.5196
#    evaluation...
# 	current CE: 0.9385, best CE: 0.9305 at epoch-48
# epoch 50/100...
# 	train CE: 0.4614
#    evaluation...
# 	current CE: 0.9294, best CE: 0.9294 at epoch-50
# epoch 51/100...
# 	train CE: 0.4406
#    evaluation...
# 	current CE: 0.9173, best CE: 0.9173 at epoch-51
# epoch 52/100...
# 	train CE: 0.4350
#    evaluation...
# 	current CE: 0.9174, best CE: 0.9173 at epoch-51
# epoch 53/100...
# 	train CE: 0.4387
#    evaluation...
# 	current CE: 0.9058, best CE: 0.9058 at epoch-53
# epoch 54/100...
# 	train CE: 0.4295
#    evaluation...
# 	current CE: 0.9080, best CE: 0.9058 at epoch-53
# epoch 55/100...
# 	train CE: 0.4114
#    evaluation...
# 	current CE: 0.9008, best CE: 0.9008 at epoch-55
# epoch 56/100...
# 	train CE: 0.4684
#    evaluation...
# 	current CE: 0.8943, best CE: 0.8943 at epoch-56
# epoch 57/100...
# 	train CE: 0.4294
#    evaluation...
# 	current CE: 0.8972, best CE: 0.8943 at epoch-56
# epoch 58/100...
# 	train CE: 0.4166
#    evaluation...
# 	current CE: 0.8960, best CE: 0.8943 at epoch-56
# epoch 59/100...
# 	train CE: 0.3885
#    evaluation...
# 	current CE: 0.8882, best CE: 0.8882 at epoch-59
# epoch 60/100...
# 	train CE: 0.4132
#    evaluation...
# 	current CE: 0.8844, best CE: 0.8844 at epoch-60
# epoch 61/100...
# 	train CE: 0.3936
#    evaluation...
# 	current CE: 0.8779, best CE: 0.8779 at epoch-61
# epoch 62/100...
# 	train CE: 0.3638
#    evaluation...
# 	current CE: 0.8782, best CE: 0.8779 at epoch-61
# epoch 63/100...
# 	train CE: 0.3389
#    evaluation...
# 	current CE: 0.8771, best CE: 0.8771 at epoch-63
# epoch 64/100...
# 	train CE: 0.4012
#    evaluation...
# 	current CE: 0.8780, best CE: 0.8771 at epoch-63
# epoch 65/100...
# 	train CE: 0.3540
#    evaluation...
# 	current CE: 0.8628, best CE: 0.8628 at epoch-65
# epoch 66/100...
# 	train CE: 0.3286
#    evaluation...
# 	current CE: 0.8629, best CE: 0.8628 at epoch-65
# epoch 67/100...
# 	train CE: 0.3441
#    evaluation...
# 	current CE: 0.8706, best CE: 0.8628 at epoch-65
# epoch 68/100...
# 	train CE: 0.3708
#    evaluation...
# 	current CE: 0.8611, best CE: 0.8611 at epoch-68
# epoch 69/100...
# 	train CE: 0.3515
#    evaluation...
# 	current CE: 0.8614, best CE: 0.8611 at epoch-68
# epoch 70/100...
# 	train CE: 0.3250
#    evaluation...
# 	current CE: 0.8602, best CE: 0.8602 at epoch-70
# epoch 71/100...
# 	train CE: 0.3617
#    evaluation...
# 	current CE: 0.8532, best CE: 0.8532 at epoch-71
# epoch 72/100...
# 	train CE: 0.3377
#    evaluation...
# 	current CE: 0.8545, best CE: 0.8532 at epoch-71
# epoch 73/100...
# 	train CE: 0.3193
#    evaluation...
# 	current CE: 0.8578, best CE: 0.8532 at epoch-71
# epoch 74/100...
# 	train CE: 0.3428
#    evaluation...
# 	current CE: 0.8498, best CE: 0.8498 at epoch-74
# epoch 75/100...
# 	train CE: 0.3157
#    evaluation...
# 	current CE: 0.8561, best CE: 0.8498 at epoch-74
# epoch 76/100...
# 	train CE: 0.3398
#    evaluation...
# 	current CE: 0.8552, best CE: 0.8498 at epoch-74
# epoch 77/100...
# 	train CE: 0.3436
#    evaluation...
# 	current CE: 0.8522, best CE: 0.8498 at epoch-74
# epoch 78/100...
# 	train CE: 0.3296
#    evaluation...
# 	current CE: 0.8536, best CE: 0.8498 at epoch-74
# epoch 79/100...
# 	train CE: 0.3304
#    evaluation...
# 	current CE: 0.8522, best CE: 0.8498 at epoch-74
# epoch 80/100...
# 	train CE: 0.3315
#    evaluation...
# 	current CE: 0.8515, best CE: 0.8498 at epoch-74
# epoch 81/100...
# 	train CE: 0.3319
#    evaluation...
# 	current CE: 0.8497, best CE: 0.8497 at epoch-81
# epoch 82/100...
# 	train CE: 0.3069
#    evaluation...
# 	current CE: 0.8525, best CE: 0.8497 at epoch-81
# epoch 83/100...
# 	train CE: 0.3339
#    evaluation...
# 	current CE: 0.8523, best CE: 0.8497 at epoch-81
# epoch 84/100...
# 	train CE: 0.3644
#    evaluation...
# 	current CE: 0.8485, best CE: 0.8485 at epoch-84
# epoch 85/100...
# 	train CE: 0.3242
#    evaluation...
# 	current CE: 0.8403, best CE: 0.8403 at epoch-85
# epoch 86/100...
# 	train CE: 0.3072
#    evaluation...
# 	current CE: 0.8446, best CE: 0.8403 at epoch-85
# epoch 87/100...
# 	train CE: 0.3059
#    evaluation...
# 	current CE: 0.8469, best CE: 0.8403 at epoch-85
# epoch 88/100...
# 	train CE: 0.3114
#    evaluation...
# 	current CE: 0.8470, best CE: 0.8403 at epoch-85
# epoch 89/100...
# 	train CE: 0.2975
#    evaluation...
# 	current CE: 0.8545, best CE: 0.8403 at epoch-85
# epoch 90/100...
# 	train CE: 0.2878
#    evaluation...
# 	current CE: 0.8440, best CE: 0.8403 at epoch-85
# epoch 91/100...
# 	train CE: 0.3318
#    evaluation...
# 	current CE: 0.8446, best CE: 0.8403 at epoch-85
# epoch 92/100...
# 	train CE: 0.3286
#    evaluation...
# 	current CE: 0.8471, best CE: 0.8403 at epoch-85
# epoch 93/100...
# 	train CE: 0.2979
#    evaluation...
# 	current CE: 0.8457, best CE: 0.8403 at epoch-85
# epoch 94/100...
# 	train CE: 0.3410
#    evaluation...
# 	current CE: 0.8424, best CE: 0.8403 at epoch-85
# epoch 95/100...
# 	train CE: 0.3189
#    evaluation...
# 	current CE: 0.8530, best CE: 0.8403 at epoch-85
# epoch 96/100...
# 	train CE: 0.2994
#    evaluation...
# 	current CE: 0.8431, best CE: 0.8403 at epoch-85
# epoch 97/100...
# 	train CE: 0.3229
#    evaluation...
# 	current CE: 0.8422, best CE: 0.8403 at epoch-85
# epoch 98/100...
# 	train CE: 0.3404
#    evaluation...
# 	current CE: 0.8543, best CE: 0.8403 at epoch-85
# epoch 99/100...
# 	train CE: 0.3285
#    evaluation...
# 	current CE: 0.8513, best CE: 0.8403 at epoch-85

# %%
plt.plot(list_train_loss, label='train loss')
plt.plot(list_val_loss, label='val loss')
plt.legend()

# %% [markdown]
# # Use the last checkpoint

# %%
myModel.eval();
predList = []
for sample in dataloader_valset:
    cur_Img, cur_Label = sample
    cur_Img = cur_Img.to(device)
    cur_Label = cur_Label.to(device)
    logits = myModel(cur_Img).detach()
    output = F.softmax(logits, dim=1)
    output = output.cpu().numpy()
    output = np.argmax(output, 1)
    predList = np.concatenate((predList, output))

# %%
conf = sklearn.metrics.confusion_matrix(val_labellist, predList, normalize='true')

plt.imshow(conf)

# %%
per_class_acc = np.diag(conf)
print('mean accuracy: %.3f' % per_class_acc.mean())
# Out:
# mean accuracy: 0.375

# %% [markdown]
# # Use the selected checkpoint

# %%
bestmodel_filename
# Out:
# './exp/vanilla_v1/bestmodel_0.000500.params'

# %%
myModel = ModelArchitecture(num_classes=numClasses).to(device)
myModel.load_state_dict(torch.load(bestmodel_filename))
# Out:
# <All keys matched successfully>

# %%
list_logits_closed_set = []
list_conf_closed_set = []
list_entropy_closed_set = []

myModel.eval();
predList = []
for sample in dataloader_valset:
    cur_Img, cur_Label = sample
    cur_Img = cur_Img.to(device)
    cur_Label = cur_Label.to(device)
    logits = myModel(cur_Img).detach()
    confidence_scores = F.softmax(logits, dim=1).cpu().numpy()
    output = np.argmax(confidence_scores, 1)
    predList = np.concatenate((predList, output))

    logits_max = np.max(logits.detach().cpu().numpy(), 1)
    list_logits_closed_set = np.concatenate((list_logits_closed_set, logits_max))

    conf_max = np.max(confidence_scores, 1)
    list_conf_closed_set = np.concatenate((list_conf_closed_set, conf_max))

    entropy_tmp = scipy.stats.entropy(confidence_scores, axis=1)
    list_entropy_closed_set = np.concatenate((list_entropy_closed_set, entropy_tmp))

# %%
list_logits_closed_set.shape, list_conf_closed_set.shape, list_entropy_closed_set.shape
# Out:
# ((120,), (120,), (120,))

# %%
conf = sklearn.metrics.confusion_matrix(val_labellist, predList, normalize='true')

plt.imshow(conf)

# %%
per_class_acc = np.diag(conf)
print('mean accuracy: %.3f' % per_class_acc.mean())
# Out:
# mean accuracy: 0.717

# %% [markdown]
# # visualize filteres at the first layer

# %%
# visualize the filters at the first layer

def visualize_first_layer_filters(model):
    """Extracts and plots the weights of the first convolutional layer."""
    # Ensure model is in evaluation mode
    model.eval()

    # 1. Find the first Conv2d layer in the model
    first_conv_layer = None
    for module in model.modules():
        if isinstance(module, torch.nn.Conv2d):
            first_conv_layer = module
            break

    if first_conv_layer is None:
        raise ValueError("No Convolutional (Conv2d) layer found in the model.")

    # 2. Extract weights and convert to CPU/numpy format
    # Shape: [out_channels, in_channels, kernel_height, kernel_width]
    weights = first_conv_layer.weight.detach().cpu()
    num_filters, in_channels, k_h, k_w = weights.shape

    print(f"First Layer Filter Shape: {list(weights.shape)}")
    print(f"Visualizing {num_filters} filters...")

    # 3. Normalize filters globally or individually to [0, 1] for proper plotting
    # Individual normalization prevents a single strong filter from dimming others
    w_min, w_max = weights.min(), weights.max()
    weights = (weights - w_min) / (w_max - w_min)

    # 4. Determine grid dimensions (as close to a square as possible)
    grid_cols = int(math.ceil(math.sqrt(num_filters)))
    grid_rows = int(math.ceil(num_filters / grid_cols))

    fig, axes = plt.subplots(grid_rows, grid_cols, figsize=(grid_cols//2, grid_rows//2))
    axes = axes.flatten()

    # 5. Plot each filter
    for i in range(num_filters):
        ax = axes[i]
        filter_weight = weights[i]

        if in_channels == 3:
            # RGB Filter: shape [3, H, W] -> convert to [H, W, 3] for matplotlib
            filter_img = filter_weight.permute(1, 2, 0).numpy()
            ax.imshow(filter_img)
        elif in_channels == 1:
            # Grayscale Filter: shape [1, H, W] -> [H, W]
            filter_img = filter_weight.squeeze(0).numpy()
            ax.imshow(filter_img, cmap="gray")
        else:
            # Multi-channel intermediate/special layers: take the average over channels
            filter_img = filter_weight.mean(dim=0).numpy()
            ax.imshow(filter_img, cmap="viridis")

        ax.axis("off")

    # Hide remaining empty subplots if the grid is larger than the filter count
    for j in range(num_filters, len(axes)):
        axes[j].axis("off")

    plt.tight_layout()
    plt.suptitle("First Layer CNN Filters", y=1.02, fontsize=16)
    plt.show()

visualize_first_layer_filters(myModel)
# Out:
# First Layer Filter Shape: [64, 3, 7, 7]
# Visualizing 64 filters...

# %% [markdown]
# # open-set recognition
#
# Let's prepare open-set images and assume that they are from unknown species. I have prepared such an open-set dataset "dataset_for_open_set" in Github (https://github.com/aimerykong/OIST-mini-course-CVML/tree/main/dataset). Please download and upload it to your gdrive. I uploaded to my gdrive folder "OIST-mini-course", where I uploaded the previous datasets "dataset_for_classification" and "dataset_for_detection".

# %%
root_folder = '/content/drive/MyDrive/OIST-mini-course'
# !ls $root_folder

dest_folder = os.path.join(root_folder, 'dataset_for_open_set')
if not os.path.isdir(dest_folder):
    zip_file = os.path.join(root_folder, 'dataset_for_open_set.zip')
    # !echo $zip_file
    # !echo $dest_folder
    # !unzip $zip_file -d $root_folder
# Out:
# cls_train.pkl
# cls_val.pkl
# code001_part-A_setup.ipynb
# code001_part-B_setup.ipynb
# code001_setup_readme.docx
# code001_setup_readme.pdf
# code002_data_prep_NN.ipynb
# code003_LogReg.ipynb
# code004_DNN_scratch.ipynb
# code005_part-A_detection_dataPrep.ipynb
# code005_part-B_pollen_detection_model_design.ipynb
# code005_part-C_pollen_detection_training.ipynb
# code006_part-A_DNN_finetune.ipynb
# code006_part-B_pollen_detection_finetune.ipynb
# dataset_for_classification
# dataset_for_classification.zip
# dataset_for_detection
# dataset_for_detection.zip
# dataset_for_open_set.zip
# det_trainval_splits.pkl
# meta_detection.pkl
# slides
# test-image.jpg
# test-image-sharpened.jpg
# /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set.zip
# /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set
# Archive:  /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set.zip
#    creating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_20-21_slide1_scan3_153_1_slice4.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_20-21_slide1_scan3_153_2_slice4.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_20-21_slide1_scan3_1_1_slice5.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_20-21_slide1_scan3_455_1_slice4.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_20-21_slide1_scan3_569_1_slice3.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_20-21_slide1_scan3_664_1_slice3.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_20-21_slide1_scan3_93_1_slice4.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_21-22_slide 1_scan1_131_2_slice6.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_21-22_slide 1_scan1_132_1_slice5.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_21-22_slide 1_scan1_59_1_slice6.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_21-22_slide 1_scan2_187_1_slice5.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_21-22_slide 1_scan2_197_1_slice4.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_21-22_slide 1_scan2_271_1_slice4.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_22-23_slide 1_scan2_195_1_slice4.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_22-23_slide 1_scan2_212_1_slice4.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_22-23_slide 1_scan2_252_1_slice3.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_22-23_slide 1_scan2_274_1_slice3.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_22-23_slide 1_scan2_306_1_slice3.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_22-23_slide 1_scan2_310_1_slice3.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_22-23_slide 1_scan2_340_1_slice4.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_22-23_slide 1_scan2_44_1_slice5.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_22-23_slide 1_scan2_57_1_slice6.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_22-23_slide 1_scan3_222_1_slice4.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_22-23_slide 1_scan3_342_1_slice4.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_22-23_slide 1_scan3_374_1_slice4.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_22-23_slide 1_scan3_374_3_slice3.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_22-23_slide 1_scan4_195_1_slice2.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_22-23_slide 1_scan4_212_1_slice2.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_22-23_slide 1_scan4_237_1_slice2.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_22-23_slide 1_scan4_243_1_slice3.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_22-23_slide 1_scan4_25_1_slice3.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_22-23_slide 1_scan4_298_1_slice1.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_22-23_slide 1_scan4_303_1_slice1.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_22-23_slide 1_scan4_313_1_slice2.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_23-24_slide 1_scan1_24_1_slice3.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_23-24_slide 1_scan1_326_1_slice2.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_23-24_slide 1_scan1_354_1_slice2.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_23-24_slide 1_scan1_397_1_slice2.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_24-25_slide 1_scan1_14_1_slice5.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_24-25_slide 1_scan1_155_1_slice6.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_24-25_slide 1_scan1_159_1_slice6.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_24-25_slide 1_scan1_15_1_slice5.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_24-25_slide 1_scan1_234_1_slice6.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_24-25_slide 1_scan1_26_1_slice6.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_24-25_slide 1_scan1_273_1_slice6.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_24-25_slide 1_scan1_281_1_slice6.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_24-25_slide 1_scan1_355_1_slice6.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_24-25_slide 1_scan1_359_1_slice6.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_24-25_slide 1_scan1_79_1_slice6.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_24-25_slide 1_scan1_95_1_slice6.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_24-25_slide 1_scan2_119_1_slice4.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_24-25_slide 1_scan2_130_1_slice4.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_24-25_slide 1_scan2_133_1_slice4.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_24-25_slide 1_scan2_139_1_slice3.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_24-25_slide 1_scan2_158_1_slice4.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_24-25_slide 1_scan2_158_3_slice4.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_24-25_slide 1_scan2_163_1_slice4.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_24-25_slide 1_scan2_177_1_slice3.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_24-25_slide 1_scan2_184_1_slice3.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_24-25_slide 1_scan2_211_1_slice5.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_24-25_slide 1_scan2_220_1_slice3.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_24-25_slide 1_scan2_277_1_slice4.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_24-25_slide 1_scan2_78_1_slice4.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_24-25_slide 1_scan2_79_1_slice4.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_24-25_slide 1_scan2_88_2_slice5.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_25-26_slide 1_scan1_122_1_slice2.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_25-26_slide 1_scan1_209_1_slice4.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_25-26_slide 1_scan2_103_1_slice7.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_25-26_slide 1_scan2_153_1_slice4.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_25-26_slide 1_scan2_184_1_slice6.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_25-26_slide 1_scan2_196_1_slice2.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_25-26_slide 1_scan2_238_1_slice2.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_25-26_slide 1_scan2_6_1_slice2.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_25-26_slide 1_scan2_99_1_slice7.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_27-28_glycerine_scan 2_173_1_slice2.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_27-28_glycerine_scan 2_231_1_slice5.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_27-28_glycerine_scan 2_275_1_slice7.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_27-28_slide 1_scan1_116_1_slice7.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_27-28_slide 1_scan1_178_1_slice4.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_27-28_slide 1_scan1_184_1_slice4.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_27-28_slide 1_scan1_236_1_slice7.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_27-28_slide 1_scan1_298_1_slice4.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_27-28_slide 1_scan1_392_1_slice8.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_27-28_slide 1_scan1_45_1_slice6.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_27-28_slide 1_scan1_4_1_slice7.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_36-37_slide 1_scan1_12_1_slice3.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_36-37_slide 1_scan1_143_1_slice4.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_36-37_slide 1_scan1_34_2_slice1.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_45-46_glycerine_slide 1_scan1_243_1_slice4.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_45-46_glycerine_slide 1_scan1_345_1_slice5.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_45-46_glycerine_slide 1_scan1_357_1_slice5.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_45-46_glycerine_slide 1_scan2_105_1_slice5.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_45-46_glycerine_slide 1_scan2_169_1_slice3.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_45-46_glycerine_slide 1_scan2_329_1_slice1.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_45-46_glycerine_slide 1_scan3_170_1_slice5.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_45-46_glycerine_slide 1_scan3_39_1_slice4.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_45-46_glycerine_slide 1_scan3_91_1_slice5.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_B_17.8_slide1_scan2_144_1_slice6.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_B_17.8_slide1_scan2_23_1_slice5.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_B_19.8_slide2_scan1_150_1_slice6.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_B_19.8_slide2_scan1_255_1_slice6.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_B_19_slide2_scan1_116_1_slice5.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_B_19_slide2_scan1_180_1_slice6.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_B_19_slide2_scan1_198_1_slice6.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_B_19_slide2_scan1_273_1_slice6.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_B_Sample_26-27_glyc_scan2_144_1_slice5.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_B_Sample_26-27_glyc_scan2_173_1_slice5.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_B_Sample_26-27_glyc_scan2_245_1_slice4.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_B_Sample_26-27_glyc_scan2_315_1_slice4.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_B_Sample_26-27_glyc_scan3_203_1_slice4.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_B_Sample_26-27_glyc_scan3_341_1_slice5.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_B_Sample_26-27_glyc_scan3_4_1_slice2.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_B_Sample_28-29_glyc_scan1_132_1_slice1.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_B_Sample_28-29_glyc_scan1_13_1_slice3.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_B_Sample_31-32_scan1_112_1_slice3.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_B_Sample_31-32_scan1_15_1_slice3.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_B_Sample_31-32_scan1_185_1_slice5.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_B_Sample_31-32_scan1_232_1_slice3.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_B_Sample_31-32_scan1_245_1_slice2.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_B_Sample_31-32_scan1_295_1_slice4.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_B_Sample_31-32_scan1_335_1_slice5.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_B_Sample_31-32_scan1_387_1_slice6.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_B_Sample_31-32_scan1_83_1_slice2.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_B_Sample_31-32_scan2_127_1_slice4.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_B_Sample_31-32_scan2_165_1_slice3.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_B_Sample_31-32_scan2_367_1_slice6.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_B_Sample_31-32_scan2_67_1_slice7.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_B_Sample_31-32_scan3_345_1_slice7.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_B_Sample_32-33_glyc_scan1_267_1_slice5.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_B_Sample_33-34_glyc_scan1_274_1_slice7.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_B_Sample_33-34_glyc_scan1_3_1_slice4.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_B_Sample_34-35_glyc_scan2_21_1_slice2.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_B_Sample_34-35_glyc_scan2_247_1_slice2.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_B_Sample_34-35_glyc_scan2_60_1_slice4.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_B_Sample_34-35_glyc_scan3_257_1_slice5.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_B_Sample_34-35_glyc_scan3_263_1_slice6.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_B_Sample_34-35_glyc_scan3_287_1_slice2.jpg
#   inflating: /content/drive/MyDrive/OIST-mini-course/dataset_for_open_set/PALIV_B_Sample_34-35_glyc_scan3_402_1_slice2.jpg

# %%
class pollenOpenSet(Dataset):
    def __init__(self, imgpathList, transform=None):
        self.imgpathList = imgpathList
        self.transform=transform
        self.current_set_len = len(imgpathList)

    def __len__(self):
        return self.current_set_len

    def __getitem__(self, idx):
        cur_img = self.imgpathList[idx]
        cur_img = skimage.io.imread(cur_img).astype(np.float32) / 255.0
        cur_img = cur_img[cur_img.shape[0]//2-64:cur_img.shape[0]//2+64,
                          cur_img.shape[1]//2-64:cur_img.shape[1]//2+64,
                          :] # suppose the new feature is a 100x100 square region in image center

        if self.transform is not None:
            cur_img = self.transform(cur_img)

        return cur_img

# %%
openSetImgList = []
source_folder = os.path.join(root_folder, 'dataset_for_open_set')  # root_folder = '/content/drive/MyDrive/OIST-mini-course'
exampleIDs = os.listdir(os.path.join(source_folder))
for i in range(len(exampleIDs)):
  openSetImgList += [os.path.join(source_folder,  exampleIDs[i])]

# %%
openset_test = pollenOpenSet(imgpathList=openSetImgList,
                             transform=data_val_transform
                             )
dataloader_openset = DataLoader(openset_test, batch_size=batch_size, shuffle=False, num_workers=1)

# %%
def imshow(img):
    img -= img.min()
    img /= img.max()
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

dataiter = iter(dataloader_openset)
images = next(dataiter)

# print images
imshow(torchvision.utils.make_grid(images))

# %%
list_logits_open_set = []
list_conf_open_set = []
list_entropy_open_set = []

myModel.eval();
for sample in dataloader_openset:
    cur_Img = sample
    cur_Img = cur_Img.to(device)
    logits = myModel(cur_Img).detach()
    confidence_scores = F.softmax(logits, dim=1).cpu().numpy()
    output = np.argmax(confidence_scores, 1)
    predList = np.concatenate((predList, output))

    logits_max = np.max(logits.detach().cpu().numpy(), 1)
    list_logits_open_set = np.concatenate((list_logits_open_set, logits_max))

    conf_max = np.max(confidence_scores, 1)
    list_conf_open_set = np.concatenate((list_conf_open_set, conf_max))

    entropy_tmp = scipy.stats.entropy(confidence_scores, axis=1)
    list_entropy_open_set = np.concatenate((list_entropy_open_set, entropy_tmp))

# %%
from sklearn.metrics import roc_curve, roc_auc_score, f1_score

def plot_roc(y_true, y_score, title="Receiver Operating Characteristic", **options):
    fpr, tpr, thresholds = roc_curve(y_true, y_score)
    auc_score = roc_auc_score(y_true, y_score)
    roc_to_plot = {'tp':tpr, 'fp':fpr, 'thresh':thresholds, 'auc_score':auc_score}
    #plot = plot_xy(fpr, tpr, x_axis="False Positive Rate", y_axis="True Positive Rate", title=title)
    #if options.get('roc_output'):
    #    print("Saving ROC scores to file")
    #    np.save(options['roc_output'], (fpr, tpr))
    #return auc_score, plot, roc_to_plot
    return auc_score, roc_to_plot


def evaluate_openset(scores_closeset, scores_openset):
    y_true = np.array([0] * len(scores_closeset) + [1] * len(scores_openset))
    y_discriminator = np.concatenate([scores_closeset, scores_openset])
    auc_d, roc_to_plot = plot_roc(y_true, y_discriminator, 'Discriminator ROC')
    return auc_d, roc_to_plot

# %% [markdown]
# ## max of softmax

# %%
list_conf_closed_set.shape, list_conf_open_set.shape,
# Out:
# ((120,), (138,))

# %%
roc_score, roc_to_plot = evaluate_openset(-list_conf_closed_set, -list_conf_open_set)

plt.plot(roc_to_plot['fp'], roc_to_plot['tp'])
plt.grid('on')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC score {:.5f}'.format(roc_score))
print(roc_score)
# Out:
# 0.9884661835748791

# %% [markdown]
# ## max of logits

# %%
list_logits_closed_set.shape, list_logits_open_set.shape
# Out:
# ((120,), (138,))

# %%
roc_score, roc_to_plot = evaluate_openset(-list_logits_closed_set, -list_logits_open_set)

plt.plot(roc_to_plot['fp'], roc_to_plot['tp'])
plt.grid('on')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC score {:.5f}'.format(roc_score))
print(roc_score)
# Out:
# 0.9772342995169082

# %% [markdown]
# ## entropy

# %%
list_entropy_closed_set.shape, list_entropy_open_set.shape
# Out:
# ((120,), (138,))

# %%
roc_score, roc_to_plot = evaluate_openset(list_entropy_closed_set, list_entropy_open_set)

plt.plot(roc_to_plot['fp'], roc_to_plot['tp'])
plt.grid('on')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC score {:.5f}'.format(roc_score))
print(roc_score)
# Out:
# 0.9951086956521739
