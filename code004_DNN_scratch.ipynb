# %%
'''
Let's import useful and "standard" packages.
Not all packages will be used in the short course.
'''

import numpy as np # numpy is a powerful package for numeric calculation, we rename it as "np"
import sys, os # these are system related packages
import pickle # pickle is a cute package to save and load your custom data
import shutil # for high-level file operations
import scipy, sklearn, skimage, math # these are useful packages for scientific computing, machine learning, image processing, and math calculation
import matplotlib.pyplot as plt # this is a powerful package for visualization, e.g., curves, bar charts, histograms, and various visualizations.
import cv2 # this is a powerful package for computer vision
from pathlib import Path
from PIL import Image
from sklearn.metrics import confusion_matrix
import random

# %%
'''
Let's import the famous PyTorch package, supporting deep learning.
It is convenient to give short names for useful functions inside PyTorch
'''
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torchvision.models as models
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.nn.functional as F
from torch.autograd import Variable
import torchvision
from torchvision import datasets, models, transforms
from torchvision.transforms import v2

# %%
def seed_everything(seed=42):
    """
    Sets the random seed for reproducibility across multiple libraries and devices.
    """
    random.seed(seed)
    np.random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed) # if you are using multi-GPU
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False # set to False for deterministic behavior
    # torch.backends.cudnn.enabled = False # can be set to False if needed
    print(f"Random seed set to {seed}")

# Usage:
seed_everything(0)
# Out:
# Random seed set to 0

# %%
# Set the global random seed for reproducibility
np.random.seed(0)


# set device, which gpu to use.
device ='cpu'
if torch.cuda.is_available():
    device='cuda:0'
print(device)
# Out:
# cuda:0

# %%
# Check the specifications of your machine/what resources you have been allocated through Colab.
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Tue Jul  7 12:08:44 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   66C    P8             14W /   70W |       3MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
from google.colab import drive # you can allow Google Colab to access your google drive, where you can save your data
drive.mount('/content/drive')
root_folder = '/content/drive/MyDrive/OIST-mini-course'
# !ls $root_folder
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# cls_train.pkl
# cls_val.pkl
# code001_part-A_setup.ipynb
# code001_part-B_setup.ipynb
# code001_setup_readme.docx
# code001_setup_readme.pdf
# code002_data_prep_NN.ipynb
# code003_LogReg.ipynb
# code004_DNN_scratch.ipynb
# code005_part-A_detection_dataPrep.ipynb
# code005_part-B_pollen_detection_model_design.ipynb
# code005_part-C_pollen_detection_training.ipynb
# code006_part-A_DNN_finetune.ipynb
# code006_part-B_pollen_detection_finetune.ipynb
# dataset_for_classification
# dataset_for_classification.zip
# dataset_for_detection
# dataset_for_detection.zip
# det_trainval_splits.pkl
# meta_detection.pkl
# slides
# test-image.jpg
# test-image-sharpened.jpg

# %% [markdown]
# # config hyperparameters

# %%
batch_size = 32
epoch_num = 100
lr = 0.0005 # base learning rate
weight_decay = 0.0005


exp_dir = './exp' # experiment directory, used for reading the init model
prefix = 'vanilla'
postfix = 'v1'

project_name = prefix + '_' + postfix   # we save all the checkpoints in this directory
print(project_name)

save_dir = os.path.join(exp_dir, project_name)

log_filename = os.path.join(save_dir, 'train_%f.log' % weight_decay)
print(save_dir)

if not os.path.exists(save_dir): os.makedirs(save_dir)
# Out:
# vanilla_v1
# ./exp/vanilla_v1

# %% [markdown]
# # make PyTorch-friendly dataloaders for train and validation sets

# %%
filename_train = os.path.join(root_folder, 'cls_train.pkl')
filename_val = os.path.join(root_folder, 'cls_val.pkl')

with open(filename_train, 'rb') as file:
    trainset_info = pickle.load(file)

with open(filename_val, 'rb') as file:
    valset_info = pickle.load(file)

train_labellist = trainset_info['train_labellist']
val_labellist = valset_info['val_labellist']

numClasses = max(train_labellist)+1

# %%
unique_labels, counts = np.unique(train_labellist, return_counts=True)


plt.figure(figsize=(8, 6))
plt.bar(unique_labels, counts, color='skyblue', edgecolor='black')

# Add axis labels and title
plt.xlabel('Label')
plt.ylabel('Frequency')
plt.title('Histogram of Labels')

# Add frequency labels on top of the bars
for i in range(len(counts)):
    plt.text(unique_labels[i], counts[i], str(counts[i]), ha='center', va='bottom')

plt.show()

# %% [markdown]
# ## a helper to read data

# %%
class pollenDataset(Dataset):
    def __init__(self, imgpathList, labelList, transform=None, is_trainset=False):
        self.imgpathList = imgpathList
        self.labelList = labelList
        self.transform=transform
        self.current_set_len = len(labelList)
        self.is_trainset = is_trainset

    def __len__(self):
        return self.current_set_len

    def __getitem__(self, idx):
        cur_img = self.imgpathList[idx]
        cur_label = self.labelList[idx]
        cur_img = skimage.io.imread(cur_img).astype(np.float32) / 255.0

        cur_img = cur_img[cur_img.shape[0]//2-64:cur_img.shape[0]//2+64,
                          cur_img.shape[1]//2-64:cur_img.shape[1]//2+64,
                          :] # suppose the new feature is a 100x100 square region in image center

        # cur_img = Image.fromarray(cur_img)
        # cur_img = Image.open(cur_img)
        # print(cur_img.max(),cur_img.min())

        if self.is_trainset:
            if np.random.rand()>0.5:
                cur_img[:,:,0] = np.fliplr(cur_img[:,:,0])
                cur_img[:,:,1] = np.fliplr(cur_img[:,:,1])
                cur_img[:,:,2] = np.fliplr(cur_img[:,:,2])
            if np.random.rand()>0.5:
                cur_img[:,:,0] = np.flipud(cur_img[:,:,0])
                cur_img[:,:,1] = np.flipud(cur_img[:,:,1])
                cur_img[:,:,2] = np.flipud(cur_img[:,:,2])


        if self.transform is not None:
            cur_img = self.transform(cur_img)
            # print('       ', cur_img.max(),cur_img.min())
        return cur_img, cur_label

# %%
IMAGENET_MEAN = [0.485, 0.456, 0.406]
IMAGENET_STD = [0.229, 0.224, 0.225]

data_train_transform = transforms.Compose([
    # v2.RandomResize(min_size=240, max_size=400),
    # transforms.RandomCrop(224),
    # transforms.RandomHorizontalFlip(),
    # transforms.RandomVerticalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(IMAGENET_MEAN, IMAGENET_STD),
])


data_val_transform = transforms.Compose([
    # transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(IMAGENET_MEAN, IMAGENET_STD),
])

# %%
trainset = pollenDataset(imgpathList=trainset_info['train_imgpathlist'],
                         labelList=train_labellist,
                         transform=data_train_transform,
                         is_trainset=True
                        )

valset = pollenDataset(imgpathList=valset_info['val_imgpathlist'],
                       labelList=val_labellist,
                       transform=data_val_transform,
                       is_trainset=False
                      )

# %%
print(len(trainset), len(valset))
# Out:
# 480 120

# %%
dataloader_trainset = DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2)
dataloader_valset = DataLoader(valset, batch_size=batch_size, shuffle=False, num_workers=2)

print(len(dataloader_trainset), len(dataloader_valset))
# Out:
# 15 4

# %%
i = 0
for sample in dataloader_valset:
    i+=1
    if i%20==0:
        print(i)
    cur_Img, cur_Label = sample
    cur_Img = cur_Img.to(device)
    cur_Label = cur_Label.to(device)

# %%
cur_Img.shape, cur_Label.shape
# Out:
# (torch.Size([24, 3, 128, 128]), torch.Size([24]))

# %% [markdown]
# # Set a Convolutional Neural Network (CNN)

# %%
class ModelArchitecture(nn.Module):
    def __init__(self, num_classes=20, pretrained=False):
        super().__init__()
        if pretrained:
            self.backbone = models.resnet18(weights='IMAGENET1K_V1') # or pretrained=True
        else:
            self.backbone = models.resnet18() # or pretrained=True
        self.backbone.fc = nn.Identity() # remove classification head
        feat_dim = 512
        self.dropout = nn.Dropout(0.5)
        self.cls_head = nn.Linear(feat_dim, num_classes)
    def forward(self, x):
        feat = self.backbone(x)
        feat = self.dropout(feat)
        logits = self.cls_head(feat)
        return logits

# %%
pretrained = False
myModel = ModelArchitecture(num_classes=numClasses, pretrained=pretrained).to(device)
myModel.train()
# Out:
# ModelArchitecture(
#   (backbone): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Identity()
#   )
#   (dropout): Dropout(p=0.5, inplace=False)
#   (cls_head): Linear(in_features=512, out_features=24, bias=True)
# )

# %%
output = myModel(cur_Img)

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = optim.AdamW(myModel.parameters(), lr=lr, betas=(0.9, 0.999), weight_decay=weight_decay)
scheduler = lr_scheduler.CosineAnnealingLR(optimizer, epoch_num, eta_min=0)

# %% [markdown]
# # Train this CNN

# %%
def append_to_log(log_filename, content_string):
    fn = open(log_filename,'a')
    fn.write('{}\n'.format(content_string))
    fn.close()

# %%
best_epoch_id = -1
best_loss = torch.inf
list_val_loss = np.zeros(epoch_num)
list_train_loss = np.zeros(epoch_num)


bestmodel_filename = os.path.join(save_dir, 'bestmodel_%f.params' % weight_decay)


fn = open(log_filename,'w')
fn.write('{}\n'.format(project_name))
fn.close()

for epoch in range(epoch_num):
    # training
    cur_string = 'epoch %d/%d...' % (epoch, epoch_num)
    print(cur_string)
    append_to_log(log_filename, cur_string)

    myModel.train();
    cur_loss = 0
    i=0
    for sample in dataloader_trainset:
        i+=1
        if i%20==0:
            cur_string = '\t%d / %d' %(i, len(dataloader_trainset))
            print(cur_string)
            append_to_log(log_filename, cur_string)

        cur_Img, cur_Label = sample
        cur_Img = cur_Img.to(device)
        cur_Label = cur_Label.to(device)
        optimizer.zero_grad()
        output = myModel(cur_Img)
        loss = loss_fn(output, cur_Label)
        cur_loss += loss.data

        # backward pass
        loss.backward()

        # update weights
        optimizer.step()

    scheduler.step()
    cur_loss = cur_loss / len(dataloader_trainset)
    list_train_loss[epoch] = cur_loss
    cur_string = '\ttrain CE: %.4f' % (cur_loss)
    print(cur_string)
    append_to_log(log_filename, cur_string)

    # evaluation
    cur_string = '   evaluation...'
    print(cur_string)
    append_to_log(log_filename, cur_string)
    myModel.eval();
    cur_loss = 0
    for sample in dataloader_valset:
        cur_Img, cur_Label = sample
        cur_Img = cur_Img.to(device)
        cur_Label = cur_Label.to(device)
        output = myModel(cur_Img)
        tmp = loss_fn(output, cur_Label)
        cur_loss += tmp.data
    cur_loss = cur_loss/len(dataloader_valset)
    list_val_loss[epoch] = cur_loss
    if cur_loss<best_loss:
        best_epoch_id = epoch
        best_loss = cur_loss
        torch.save(myModel.state_dict(), bestmodel_filename)
    cur_string = '\tcurrent CE: %.4f, best CE: %.4f at epoch-%d' % (cur_loss, best_loss, best_epoch_id)
    print(cur_string)
    append_to_log(log_filename, cur_string)
# Out:
# epoch 0/100...
# 	train CE: 3.0673
#    evaluation...
# 	current CE: 4.0516, best CE: 4.0516 at epoch-0
# epoch 1/100...
# 	train CE: 2.4849
#    evaluation...
# 	current CE: 3.2284, best CE: 3.2284 at epoch-1
# epoch 2/100...
# 	train CE: 2.1507
#    evaluation...
# 	current CE: 2.2824, best CE: 2.2824 at epoch-2
# epoch 3/100...
# 	train CE: 1.9025
#    evaluation...
# 	current CE: 2.1641, best CE: 2.1641 at epoch-3
# epoch 4/100...
# 	train CE: 1.7550
#    evaluation...
# 	current CE: 5.4308, best CE: 2.1641 at epoch-3
# epoch 5/100...
# 	train CE: 1.7696
#    evaluation...
# 	current CE: 3.2805, best CE: 2.1641 at epoch-3
# epoch 6/100...
# 	train CE: 1.5059
#    evaluation...
# 	current CE: 2.5789, best CE: 2.1641 at epoch-3
# epoch 7/100...
# 	train CE: 1.3730
#    evaluation...
# 	current CE: 2.3661, best CE: 2.1641 at epoch-3
# epoch 8/100...
# 	train CE: 1.1069
#    evaluation...
# 	current CE: 2.1670, best CE: 2.1641 at epoch-3
# epoch 9/100...
# 	train CE: 1.0170
#    evaluation...
# 	current CE: 3.1680, best CE: 2.1641 at epoch-3
# epoch 10/100...
# 	train CE: 1.0098
#    evaluation...
# 	current CE: 2.1852, best CE: 2.1641 at epoch-3
# epoch 11/100...
# 	train CE: 0.9949
#    evaluation...
# 	current CE: 2.2894, best CE: 2.1641 at epoch-3
# epoch 12/100...
# 	train CE: 0.8156
#    evaluation...
# 	current CE: 3.1878, best CE: 2.1641 at epoch-3
# epoch 13/100...
# 	train CE: 0.7193
#    evaluation...
# 	current CE: 2.6086, best CE: 2.1641 at epoch-3
# epoch 14/100...
# 	train CE: 0.6333
#    evaluation...
# 	current CE: 1.7837, best CE: 1.7837 at epoch-14
# epoch 15/100...
# 	train CE: 0.5863
#    evaluation...
# 	current CE: 2.4837, best CE: 1.7837 at epoch-14
# epoch 16/100...
# 	train CE: 0.5107
#    evaluation...
# 	current CE: 1.8949, best CE: 1.7837 at epoch-14
# epoch 17/100...
# 	train CE: 0.4497
#    evaluation...
# 	current CE: 1.8531, best CE: 1.7837 at epoch-14
# epoch 18/100...
# 	train CE: 0.3867
#    evaluation...
# 	current CE: 2.8513, best CE: 1.7837 at epoch-14
# epoch 19/100...
# 	train CE: 0.3810
#    evaluation...
# 	current CE: 2.0083, best CE: 1.7837 at epoch-14
# epoch 20/100...
# 	train CE: 0.4016
#    evaluation...
# 	current CE: 2.1318, best CE: 1.7837 at epoch-14
# epoch 21/100...
# 	train CE: 0.3264
#    evaluation...
# 	current CE: 2.0412, best CE: 1.7837 at epoch-14
# epoch 22/100...
# 	train CE: 0.2569
#    evaluation...
# 	current CE: 1.7538, best CE: 1.7538 at epoch-22
# epoch 23/100...
# 	train CE: 0.1897
#    evaluation...
# 	current CE: 1.9234, best CE: 1.7538 at epoch-22
# epoch 24/100...
# 	train CE: 0.1753
#    evaluation...
# 	current CE: 1.8060, best CE: 1.7538 at epoch-22
# epoch 25/100...
# 	train CE: 0.2480
#    evaluation...
# 	current CE: 2.4796, best CE: 1.7538 at epoch-22
# epoch 26/100...
# 	train CE: 0.1954
#    evaluation...
# 	current CE: 2.1883, best CE: 1.7538 at epoch-22
# epoch 27/100...
# 	train CE: 0.1941
#    evaluation...
# 	current CE: 2.1432, best CE: 1.7538 at epoch-22
# epoch 28/100...
# 	train CE: 0.1743
#    evaluation...
# 	current CE: 1.9558, best CE: 1.7538 at epoch-22
# epoch 29/100...
# 	train CE: 0.2003
#    evaluation...
# 	current CE: 3.2321, best CE: 1.7538 at epoch-22
# epoch 30/100...
# 	train CE: 0.2144
#    evaluation...
# 	current CE: 1.8233, best CE: 1.7538 at epoch-22
# epoch 31/100...
# 	train CE: 0.1880
#    evaluation...
# 	current CE: 1.9605, best CE: 1.7538 at epoch-22
# epoch 32/100...
# 	train CE: 0.0937
#    evaluation...
# 	current CE: 1.8239, best CE: 1.7538 at epoch-22
# epoch 33/100...
# 	train CE: 0.1034
#    evaluation...
# 	current CE: 2.0144, best CE: 1.7538 at epoch-22
# epoch 34/100...
# 	train CE: 0.1164
#    evaluation...
# 	current CE: 1.8118, best CE: 1.7538 at epoch-22
# epoch 35/100...
# 	train CE: 0.0786
#    evaluation...
# 	current CE: 1.9909, best CE: 1.7538 at epoch-22
# epoch 36/100...
# 	train CE: 0.0707
#    evaluation...
# 	current CE: 1.9261, best CE: 1.7538 at epoch-22
# epoch 37/100...
# 	train CE: 0.0816
#    evaluation...
# 	current CE: 1.8117, best CE: 1.7538 at epoch-22
# epoch 38/100...
# 	train CE: 0.0786
#    evaluation...
# 	current CE: 1.7963, best CE: 1.7538 at epoch-22
# epoch 39/100...
# 	train CE: 0.0406
#    evaluation...
# 	current CE: 2.0475, best CE: 1.7538 at epoch-22
# epoch 40/100...
# 	train CE: 0.0341
#    evaluation...
# 	current CE: 1.7540, best CE: 1.7538 at epoch-22
# epoch 41/100...
# 	train CE: 0.0391
#    evaluation...
# 	current CE: 1.7426, best CE: 1.7426 at epoch-41
# epoch 42/100...
# 	train CE: 0.0357
#    evaluation...
# 	current CE: 1.8539, best CE: 1.7426 at epoch-41
# epoch 43/100...
# 	train CE: 0.0264
#    evaluation...
# 	current CE: 1.7324, best CE: 1.7324 at epoch-43
# epoch 44/100...
# 	train CE: 0.0301
#    evaluation...
# 	current CE: 1.8269, best CE: 1.7324 at epoch-43
# epoch 45/100...
# 	train CE: 0.0305
#    evaluation...
# 	current CE: 1.7774, best CE: 1.7324 at epoch-43
# epoch 46/100...
# 	train CE: 0.0155
#    evaluation...
# 	current CE: 1.8065, best CE: 1.7324 at epoch-43
# epoch 47/100...
# 	train CE: 0.0156
#    evaluation...
# 	current CE: 1.6656, best CE: 1.6656 at epoch-47
# epoch 48/100...
# 	train CE: 0.0158
#    evaluation...
# 	current CE: 1.8369, best CE: 1.6656 at epoch-47
# epoch 49/100...
# 	train CE: 0.0277
#    evaluation...
# 	current CE: 1.6716, best CE: 1.6656 at epoch-47
# epoch 50/100...
# 	train CE: 0.0090
#    evaluation...
# 	current CE: 1.6217, best CE: 1.6217 at epoch-50
# epoch 51/100...
# 	train CE: 0.0171
#    evaluation...
# 	current CE: 1.7057, best CE: 1.6217 at epoch-50
# epoch 52/100...
# 	train CE: 0.0133
#    evaluation...
# 	current CE: 1.6334, best CE: 1.6217 at epoch-50
# epoch 53/100...
# 	train CE: 0.0199
#    evaluation...
# 	current CE: 1.6573, best CE: 1.6217 at epoch-50
# epoch 54/100...
# 	train CE: 0.0057
#    evaluation...
# 	current CE: 1.5988, best CE: 1.5988 at epoch-54
# epoch 55/100...
# 	train CE: 0.0075
#    evaluation...
# 	current CE: 1.6115, best CE: 1.5988 at epoch-54
# epoch 56/100...
# 	train CE: 0.0096
#    evaluation...
# 	current CE: 1.6747, best CE: 1.5988 at epoch-54
# epoch 57/100...
# 	train CE: 0.0077
#    evaluation...
# 	current CE: 1.6675, best CE: 1.5988 at epoch-54
# epoch 58/100...
# 	train CE: 0.0071
#    evaluation...
# 	current CE: 1.7059, best CE: 1.5988 at epoch-54
# epoch 59/100...
# 	train CE: 0.0063
#    evaluation...
# 	current CE: 1.7165, best CE: 1.5988 at epoch-54
# epoch 60/100...
# 	train CE: 0.0041
#    evaluation...
# 	current CE: 1.7065, best CE: 1.5988 at epoch-54
# epoch 61/100...
# 	train CE: 0.0045
#    evaluation...
# 	current CE: 1.7193, best CE: 1.5988 at epoch-54
# epoch 62/100...
# 	train CE: 0.0039
#    evaluation...
# 	current CE: 1.7087, best CE: 1.5988 at epoch-54
# epoch 63/100...
# 	train CE: 0.0033
#    evaluation...
# 	current CE: 1.6755, best CE: 1.5988 at epoch-54
# epoch 64/100...
# 	train CE: 0.0048
#    evaluation...
# 	current CE: 1.6712, best CE: 1.5988 at epoch-54
# epoch 65/100...
# 	train CE: 0.0039
#    evaluation...
# 	current CE: 1.6559, best CE: 1.5988 at epoch-54
# epoch 66/100...
# 	train CE: 0.0033
#    evaluation...
# 	current CE: 1.6427, best CE: 1.5988 at epoch-54
# epoch 67/100...
# 	train CE: 0.0037
#    evaluation...
# 	current CE: 1.6764, best CE: 1.5988 at epoch-54
# epoch 68/100...
# 	train CE: 0.0041
#    evaluation...
# 	current CE: 1.6367, best CE: 1.5988 at epoch-54
# epoch 69/100...
# 	train CE: 0.0054
#    evaluation...
# 	current CE: 1.6423, best CE: 1.5988 at epoch-54
# epoch 70/100...
# 	train CE: 0.0030
#    evaluation...
# 	current CE: 1.6373, best CE: 1.5988 at epoch-54
# epoch 71/100...
# 	train CE: 0.0043
#    evaluation...
# 	current CE: 1.6607, best CE: 1.5988 at epoch-54
# epoch 72/100...
# 	train CE: 0.0036
#    evaluation...
# 	current CE: 1.6892, best CE: 1.5988 at epoch-54
# epoch 73/100...
# 	train CE: 0.0044
#    evaluation...
# 	current CE: 1.6693, best CE: 1.5988 at epoch-54
# epoch 74/100...
# 	train CE: 0.0039
#    evaluation...
# 	current CE: 1.6657, best CE: 1.5988 at epoch-54
# epoch 75/100...
# 	train CE: 0.0031
#    evaluation...
# 	current CE: 1.6477, best CE: 1.5988 at epoch-54
# epoch 76/100...
# 	train CE: 0.0036
#    evaluation...
# 	current CE: 1.6457, best CE: 1.5988 at epoch-54
# epoch 77/100...
# 	train CE: 0.0038
#    evaluation...
# 	current CE: 1.6762, best CE: 1.5988 at epoch-54
# epoch 78/100...
# 	train CE: 0.0030
#    evaluation...
# 	current CE: 1.6672, best CE: 1.5988 at epoch-54
# epoch 79/100...
# 	train CE: 0.0037
#    evaluation...
# 	current CE: 1.6773, best CE: 1.5988 at epoch-54
# epoch 80/100...
# 	train CE: 0.0028
#    evaluation...
# 	current CE: 1.6646, best CE: 1.5988 at epoch-54
# epoch 81/100...
# 	train CE: 0.0034
#    evaluation...
# 	current CE: 1.6603, best CE: 1.5988 at epoch-54
# epoch 82/100...
# 	train CE: 0.0033
#    evaluation...
# 	current CE: 1.6716, best CE: 1.5988 at epoch-54
# epoch 83/100...
# 	train CE: 0.0035
#    evaluation...
# 	current CE: 1.6917, best CE: 1.5988 at epoch-54
# epoch 84/100...
# 	train CE: 0.0038
#    evaluation...
# 	current CE: 1.6877, best CE: 1.5988 at epoch-54
# epoch 85/100...
# 	train CE: 0.0045
#    evaluation...
# 	current CE: 1.6925, best CE: 1.5988 at epoch-54
# epoch 86/100...
# 	train CE: 0.0046
#    evaluation...
# 	current CE: 1.7052, best CE: 1.5988 at epoch-54
# epoch 87/100...
# 	train CE: 0.0033
#    evaluation...
# 	current CE: 1.6899, best CE: 1.5988 at epoch-54
# epoch 88/100...
# 	train CE: 0.0028
#    evaluation...
# 	current CE: 1.6844, best CE: 1.5988 at epoch-54
# epoch 89/100...
# 	train CE: 0.0025
#    evaluation...
# 	current CE: 1.6894, best CE: 1.5988 at epoch-54
# epoch 90/100...
# 	train CE: 0.0029
#    evaluation...
# 	current CE: 1.6964, best CE: 1.5988 at epoch-54
# epoch 91/100...
# 	train CE: 0.0035
#    evaluation...
# 	current CE: 1.6925, best CE: 1.5988 at epoch-54
# epoch 92/100...
# 	train CE: 0.0033
#    evaluation...
# 	current CE: 1.6827, best CE: 1.5988 at epoch-54
# epoch 93/100...
# 	train CE: 0.0025
#    evaluation...
# 	current CE: 1.6706, best CE: 1.5988 at epoch-54
# epoch 94/100...
# 	train CE: 0.0036
#    evaluation...
# 	current CE: 1.6660, best CE: 1.5988 at epoch-54
# epoch 95/100...
# 	train CE: 0.0034
#    evaluation...
# 	current CE: 1.6903, best CE: 1.5988 at epoch-54
# epoch 96/100...
# 	train CE: 0.0035
#    evaluation...
# 	current CE: 1.6880, best CE: 1.5988 at epoch-54
# epoch 97/100...
# 	train CE: 0.0032
#    evaluation...
# 	current CE: 1.6907, best CE: 1.5988 at epoch-54
# epoch 98/100...
# 	train CE: 0.0046
#    evaluation...
# 	current CE: 1.6949, best CE: 1.5988 at epoch-54
# epoch 99/100...
# 	train CE: 0.0045
#    evaluation...
# 	current CE: 1.7159, best CE: 1.5988 at epoch-54

# %%
plt.plot(list_train_loss, label='train loss')
plt.plot(list_val_loss, label='val loss')
plt.legend()

# %% [markdown]
# # Use the last checkpoint

# %%
myModel.eval();
predList = []
for sample in dataloader_valset:
    cur_Img, cur_Label = sample
    cur_Img = cur_Img.to(device)
    cur_Label = cur_Label.to(device)
    logits = myModel(cur_Img).detach()
    output = F.softmax(logits, dim=0)
    output = output.cpu().numpy()
    output = np.argmax(output, 1)
    predList = np.concatenate((predList, output))

# %%
conf = sklearn.metrics.confusion_matrix(val_labellist, predList, normalize='true')

plt.imshow(conf)

# %%
per_class_acc = np.diag(conf)
print('mean accuracy: %.3f' % per_class_acc.mean())
# Out:
# mean accuracy: 0.283

# %% [markdown]
# # Use the selected checkpoint

# %%
bestmodel_filename
# Out:
# './exp/vanilla_v1/bestmodel_0.000500.params'

# %%
myModel = ModelArchitecture(num_classes=numClasses).to(device)
myModel.load_state_dict(torch.load(bestmodel_filename))
# Out:
# <All keys matched successfully>

# %%
myModel.eval();
predList = []
for sample in dataloader_valset:
    cur_Img, cur_Label = sample
    cur_Img = cur_Img.to(device)
    cur_Label = cur_Label.to(device)
    logits = myModel(cur_Img).detach()
    output = F.softmax(logits, dim=0)
    output = output.cpu().numpy()
    output = np.argmax(output, 1)
    predList = np.concatenate((predList, output))

# %%
conf = sklearn.metrics.confusion_matrix(val_labellist, predList, normalize='true')

plt.imshow(conf)

# %%
per_class_acc = np.diag(conf)
print('mean accuracy: %.3f' % per_class_acc.mean())
# Out:
# mean accuracy: 0.292

# %% [markdown]
# # visualize the filters at the first layer

# %%
# visualize the filters at the first layer

def visualize_first_layer_filters(model):
    """Extracts and plots the weights of the first convolutional layer."""
    # Ensure model is in evaluation mode
    model.eval()

    # 1. Find the first Conv2d layer in the model
    first_conv_layer = None
    for module in model.modules():
        if isinstance(module, torch.nn.Conv2d):
            first_conv_layer = module
            break

    if first_conv_layer is None:
        raise ValueError("No Convolutional (Conv2d) layer found in the model.")

    # 2. Extract weights and convert to CPU/numpy format
    # Shape: [out_channels, in_channels, kernel_height, kernel_width]
    weights = first_conv_layer.weight.detach().cpu()
    num_filters, in_channels, k_h, k_w = weights.shape

    print(f"First Layer Filter Shape: {list(weights.shape)}")
    print(f"Visualizing {num_filters} filters...")

    # 3. Normalize filters globally or individually to [0, 1] for proper plotting
    # Individual normalization prevents a single strong filter from dimming others
    w_min, w_max = weights.min(), weights.max()
    weights = (weights - w_min) / (w_max - w_min)

    # 4. Determine grid dimensions (as close to a square as possible)
    grid_cols = int(math.ceil(math.sqrt(num_filters)))
    grid_rows = int(math.ceil(num_filters / grid_cols))

    fig, axes = plt.subplots(grid_rows, grid_cols, figsize=(grid_cols//2, grid_rows//2))
    axes = axes.flatten()

    # 5. Plot each filter
    for i in range(num_filters):
        ax = axes[i]
        filter_weight = weights[i]

        if in_channels == 3:
            # RGB Filter: shape [3, H, W] -> convert to [H, W, 3] for matplotlib
            filter_img = filter_weight.permute(1, 2, 0).numpy()
            ax.imshow(filter_img)
        elif in_channels == 1:
            # Grayscale Filter: shape [1, H, W] -> [H, W]
            filter_img = filter_weight.squeeze(0).numpy()
            ax.imshow(filter_img, cmap="gray")
        else:
            # Multi-channel intermediate/special layers: take the average over channels
            filter_img = filter_weight.mean(dim=0).numpy()
            ax.imshow(filter_img, cmap="viridis")

        ax.axis("off")

    # Hide remaining empty subplots if the grid is larger than the filter count
    for j in range(num_filters, len(axes)):
        axes[j].axis("off")

    plt.tight_layout()
    plt.suptitle("First Layer CNN Filters", y=1.02, fontsize=16)
    plt.show()

visualize_first_layer_filters(myModel)
# Out:
# First Layer Filter Shape: [64, 3, 7, 7]
# Visualizing 64 filters...
